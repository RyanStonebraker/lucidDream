# %%
import gpt_2_simple as gpt2
import tensorflow as tf
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
import pandas as pd
import re

# %%
seed = "The person was walking to the store when"

# %%
gpt2.download_gpt2(model_name="355M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 455Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.10Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 668Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [01:18, 18.2Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 398Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 3.13Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 3.90Mit/s]

# %%
# %run Emotion\ Profiler.ipynb
# Out:
# <table style='display: inline' border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>idf_weights</th>
#     </tr>
#     <tr>
#       <th>anger</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>angry</th>
#       <td>2.764360</td>
#     </tr>
#     <tr>
#       <th>friend</th>
#       <td>2.928471</td>
#     </tr>
#     <tr>
#       <th>one</th>
#       <td>3.340325</td>
#     </tr>
#     <tr>
#       <th>got</th>
#       <td>3.615268</td>
#     </tr>
#     <tr>
#       <th>time</th>
#       <td>3.640911</td>
#     </tr>
#     <tr>
#       <th>told</th>
#       <td>3.680651</td>
#     </tr>
#     <tr>
#       <th>felt</th>
#       <td>3.736221</td>
#     </tr>
#     <tr>
#       <th>person</th>
#       <td>3.841582</td>
#     </tr>
#     <tr>
#       <th>people</th>
#       <td>3.873842</td>
#     </tr>
#     <tr>
#       <th>someone</th>
#       <td>3.890372</td>
#     </tr>
#     <tr>
# ...

# %%
sess = gpt2.start_tf_sess()
for emotion in isear_df.emotion.unique().tolist():
# for emotion in ["sadness"]:
    gpt2.reset_session(sess)
    sess = gpt2.start_tf_sess()
    gpt2.finetune(
        sess,
        f"../corpora/emotions/{emotion}.txt",
        model_name="355M",
        steps=1000,
        restore_from="fresh",
        run_name=f"{emotion}_run1",
        print_every=10,
        sample_every=200,
        save_every=500
    )
# Out:
# WARNING:tensorflow:From /home/ryan/anaconda3/lib/python3.7/site-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/ryan/anaconda3/lib/python3.7/site-packages/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00,  2.49it/s]
# dataset has 25705 tokens
# Training...
# [10 | 25.61] loss=2.77 avg=2.77
# [20 | 38.17] loss=1.90 avg=2.33
# ...

# %%
emo = "sad"
gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.load_gpt2(sess, run_name=emo)

gpt2.generate(
    sess,
    length=50,
    temperature=0.7,
    prefix="I think today will be",
    nsamples=1,
    batch_size=1,
    run_name=f"{emo}_run1"
)
# Out:
# I think today will be the last time that I will ever run for office.
# When my mother died.
# When my brother committed suicide.
# When I was betrayed by my friend and I lost my job.
# I feel sad about the way people treat animals and nature

# %%
sess = gpt2.start_tf_sess()

# %%
character = "full_model"

gpt2.reset_session(sess)
sess = gpt2.start_tf_sess()
gpt2.finetune(
    sess,
    f"../corpora/harry_potter/full_text.txt",
    model_name="355M",
    steps=1000,
    restore_from="fresh",
    run_name=f"{character}_run1",
    print_every=10,
    sample_every=200,
    save_every=500
)
# Out:
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loading dataset...
# 100%|██████████| 1/1 [00:01<00:00,  1.14s/it]
# dataset has 92342 tokens
# Training...
# [10 | 26.84] loss=3.30 avg=3.30
# [20 | 40.15] loss=2.86 avg=3.08
# [30 | 53.41] loss=2.53 avg=2.90
# [40 | 66.72] loss=2.39 avg=2.77
# [50 | 80.01] loss=2.39 avg=2.69
# [60 | 93.35] loss=2.18 avg=2.60
# [70 | 106.85] loss=2.20 avg=2.54
# [80 | 120.18] loss=1.35 avg=2.39
# [90 | 133.49] loss=2.67 avg=2.42
# [100 | 146.82] loss=2.23 avg=2.40
# [110 | 160.12] loss=2.07 avg=2.37
# [120 | 173.39] loss=1.78 avg=2.32
# [130 | 186.71] loss=1.46 avg=2.25
# [140 | 199.96] loss=2.84 avg=2.29
# [150 | 213.29] loss=2.80 avg=2.33
# [160 | 226.65] loss=2.64 avg=2.35
# [170 | 240.03] loss=2.05 avg=2.33
# [180 | 253.40] loss=1.50 avg=2.28
# [190 | 266.82] loss=2.58 avg=2.30
# [200 | 280.23] loss=0.65 avg=2.21
# ======== SAMPLE 1 ========
# )
# ...

# %%
gpt2.generate(
    sess,
    length=25,
    temperature=0.7,
    prefix="environment: The dark mark shined in the sky.\nsnape:",
    nsamples=1,
    batch_size=1,
    run_name="snape_run1"
)
# Out:
# environment: The dark mark shined in the sky.
# snape:  Mr. Potter. Our...new...celebrity. Tell me, what would I get if I added powdered root

# %%
for emotion, row in character_profiles["harry"].iterrows():
    print(emotion, row.percent)
# Out:
# disgust 0.1648003693706231
# anger 0.15647319632351026
# fear 0.15555055201494097
# guilt 0.14739040651343888
# shame 0.14720370046697356
# joy 0.12097886589742116
# sadness 0.10760290941309218
